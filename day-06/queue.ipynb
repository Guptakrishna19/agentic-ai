# %%
## queue
from collections import deque

q=deque()

print(q)
# Out:
# deque([])

# %%
q.append(34)
q.append(14)
q.appendleft(44)
q.appendleft(45)
q.appendleft(18)

# %%
print(q)
# Out:
# deque([18, 45, 44, 34, 14])

# %%
q.popleft()
# Out:
# 18

# %%
q.pop()
# Out:
# 14

# %%
print(q)
# Out:
# deque([45, 44, 34])

# %%
#peek from left 

q[0]
# Out:
# 45

# %%
#peek from right 

q[-1]
# Out:
# 34

# %%
class Solution(object):
    def removeElement(self, nums, val):
        for i in range(len(nums)):
            if val!=nums[i]:
                return c+=1

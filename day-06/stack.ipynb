# %%
## stacks

stk=[]

stk.append(21)
stk.append(1)
stk.append(2)
stk.append(45)
stk.append(18)
stk.append(7)

print(stk)
# Out:
# [21, 1, 2, 45, 18, 7]

# %%
popped_item=stk.pop(3)
print(popped_item)
print(stk)
# Out:
# 45
# [21, 1, 2, 18, 7]

# %%
## elemnt at the top

peek=stk[-1]
print(peek)
# Out:
# 7

# %%
if stk:
    print(True)
# Out:
# True

# %%
print(stk)
# Out:
# [21, 1, 2, 18, 7]
